# %%
# %matplotlib inline
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
import sqlite3

# %%
con = sqlite3.connect('../datasets/spotify/charts.sqlite')

# %%
charts = pd.read_sql_query("SELECT * from top200", con)
charts
# Out:
#                                  title  rank        date             artist  \
# 0                             good 4 u     1  2021-06-23     Olivia Rodrigo
# 1                           Todo De Ti     2  2021-06-23     Rauw Alejandro
# 2       MONTERO (Call Me By Your Name)     3  2021-06-23          Lil Nas X
# 3                             Yonaguni     4  2021-06-23          Bad Bunny
# 4             Kiss Me More (feat. SZA)     5  2021-06-23           Doja Cat
# ...                                ...   ...         ...                ...
# 326195                   White Iverson   196  2017-01-01        Post Malone
# 326196                         Oh Lord   197  2017-01-01          MiC LOWRY
# 326197   Superstition - Single Version   198  2017-01-01      Stevie Wonder
# 326198                         Secrets   199  2017-01-01         The Weeknd
# 326199                 Ni**as In Paris   200  2017-01-01  JAY-Z, Kanye West
#
#                                                       url          trend  \
# 0       https://open.spotify.com/track/4ZtFanR9U6ndgdd...  SAME_POSITION
# 1       https://open.spotify.com/track/4fSIb4hdOQ151TI...  SAME_POSITION
# 2       https://open.spotify.com/track/67BtfxlNbhBmCDR...  SAME_POSITION
# 3       https://open.spotify.com/track/2JPLbjOn0wPCngE...  SAME_POSITION
# 4       https://open.spotify.com/track/748mdHapucXQri7...  SAME_POSITION
# ...                                                   ...            ...
# 326195  https://open.spotify.com/track/6eT7xZZlB2mwyzJ...      NEW_ENTRY
# 326196  https://open.spotify.com/track/1sTUEdVO85YU8Ym...      MOVE_DOWN
# 326197  https://open.spotify.com/track/5lXcSvHRVjQJ3LB...      NEW_ENTRY
# 326198  https://open.spotify.com/track/3DX4Y0egvc0slLc...      NEW_ENTRY
# 326199  https://open.spotify.com/track/2KpCpk6HjXXLb7n...      NEW_ENTRY
#
#         streams
# 0       7397613
# 1       5138644
# 2       5089504
# 3       4936579
# 4       4612404
# ...         ...
# 326195   332756
# 326196   331792
# 326197   331376
# 326198   331233
# 326199   325951
#
# [326200 rows x 7 columns]

# %%
charts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 326200 entries, 0 to 326199
# Data columns (total 7 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   title    326200 non-null  object
#  1   rank     326200 non-null  int64
#  2   date     326200 non-null  object
#  3   artist   326200 non-null  object
#  4   url      326200 non-null  object
#  5   trend    326200 non-null  object
#  6   streams  326200 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 17.4+ MB

# %%
charts['date']= pd.to_datetime(charts['date'])

# %%
charts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 326200 entries, 0 to 326199
# Data columns (total 7 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   title    326200 non-null  object
#  1   rank     326200 non-null  int64
#  2   date     326200 non-null  datetime64[ns]
#  3   artist   326200 non-null  object
#  4   url      326200 non-null  object
#  5   trend    326200 non-null  object
#  6   streams  326200 non-null  int64
# dtypes: datetime64[ns](1), int64(2), object(4)
# memory usage: 17.4+ MB

# %%
number_one_ranks = charts[charts['rank'] == 1]
number_one_ranks
# Out:
#            title  rank       date                 artist  \
# 0       good 4 u     1 2021-06-23         Olivia Rodrigo
# 200     good 4 u     1 2021-06-22         Olivia Rodrigo
# 400     good 4 u     1 2021-06-21         Olivia Rodrigo
# 600     good 4 u     1 2021-06-20         Olivia Rodrigo
# 800     good 4 u     1 2021-06-19         Olivia Rodrigo
# ...          ...   ...        ...                    ...
# 325200   Starboy     1 2017-01-05  The Weeknd, Daft Punk
# 325400   Starboy     1 2017-01-04  The Weeknd, Daft Punk
# 325600   Starboy     1 2017-01-03  The Weeknd, Daft Punk
# 325800   Starboy     1 2017-01-02  The Weeknd, Daft Punk
# 326000   Starboy     1 2017-01-01  The Weeknd, Daft Punk
#
#                                                       url          trend  \
# 0       https://open.spotify.com/track/4ZtFanR9U6ndgdd...  SAME_POSITION
# 200     https://open.spotify.com/track/4ZtFanR9U6ndgdd...  SAME_POSITION
# 400     https://open.spotify.com/track/4ZtFanR9U6ndgdd...  SAME_POSITION
# 600     https://open.spotify.com/track/4ZtFanR9U6ndgdd...  SAME_POSITION
# 800     https://open.spotify.com/track/4ZtFanR9U6ndgdd...  SAME_POSITION
# ...                                                   ...            ...
# 325200  https://open.spotify.com/track/5aAx2yezTd8zXrk...  SAME_POSITION
# 325400  https://open.spotify.com/track/5aAx2yezTd8zXrk...  SAME_POSITION
# 325600  https://open.spotify.com/track/5aAx2yezTd8zXrk...  SAME_POSITION
# 325800  https://open.spotify.com/track/5aAx2yezTd8zXrk...  SAME_POSITION
# 326000  https://open.spotify.com/track/5aAx2yezTd8zXrk...  SAME_POSITION
#
#         streams
# 0       7397613
# 200     7973877
# 400     7851007
# 600     7403306
# 800     8221390
# ...         ...
# 325200  3579206
# 325400  3619247
# 325600  3563076
# 325800  3342769
# 326000  3135625
#
# [1631 rows x 7 columns]

# %%
number_one_list = number_one_ranks['title'].unique()
number_one_list
# Out:
# array(['good 4 u', 'MONTERO (Call Me By Your Name)', 'a m a r i',
#        'Peaches (feat. Daniel Caesar & Giveon)', 'drivers license',
#        'What’s Next', 'DÁKITI', 'All I Want for Christmas Is You',
#        'willow', 'positions', 'Mood (feat. iann dior)',
#        'WAP (feat. Megan Thee Stallion)', 'Dynamite',
#        'Savage Love (Laxed - Siren Beat)', 'my future',
#        'ROCKSTAR (feat. Roddy Ricch)', 'cardigan', 'Blinding Lights',
#        'Rain On Me (with Ariana Grande)',
#        'Stuck with U (with Justin Bieber)', 'Toosie Slide', 'THE SCOTTS',
#        'Dance Monkey', 'No Time To Die', 'The Box', 'everything i wanted',
#        'Lose You To Love Me', 'HIGHEST IN THE ROOM', 'Señorita',
#        'Circles', "I Don't Care (with Justin Bieber)", 'bad guy',
#        'ME! (feat. Brendon Urie of Panic! At The Disco)', '7 rings',
#        'Con Calma', 'Sunflower - Spider-Man: Into the Spider-Verse',
#        'thank u, next', 'Wow.',
#        'Taki Taki (with Selena Gomez, Ozuna & Cardi B)',
#        'MIA (feat. Drake)', 'I Love It (& Lil Pump)',
#        'Mona Lisa (feat. Kendrick Lamar)', 'In My Feelings',
#        'Lucky You (feat. Joyner Lucas)', 'The Ringer',
#        'Don’t Matter To Me', 'Nonstop', 'SAD!', 'Better Now', 'All Mine',
#        'One Kiss (with Dua Lipa)', 'This Is America',
#        'Psycho (feat. Ty Dolla $ign)', 'Nice For What', "God's Plan",
#        'Call Out My Name', 'Havana (feat. Young Thug)', 'rockstar',
#        'Mi Gente', 'Too Good At Goodbyes - Edit',
#        'Look What You Made Me Do', 'Despacito - Remix',
#        'Despacito (Featuring Daddy Yankee)', 'HUMBLE.', 'Shape of You',
#        'Starboy'], dtype=object)

# %%
'All I Want for Christmas Is You' in number_one_list
# Out:
# True

# %%
number_ones = charts.loc[charts.title.isin(number_one_list)]
number_ones
# Out:
#                                          title  rank       date  \
# 0                                     good 4 u     1 2021-06-23
# 2               MONTERO (Call Me By Your Name)     3 2021-06-23
# 8       Peaches (feat. Daniel Caesar & Giveon)     9 2021-06-23
# 16                             drivers license    17 2021-06-23
# 23                             Blinding Lights    24 2021-06-23
# ...                                        ...   ...        ...
# 325200                                 Starboy     1 2017-01-05
# 325400                                 Starboy     1 2017-01-04
# 325600                                 Starboy     1 2017-01-03
# 325800                                 Starboy     1 2017-01-02
# 326000                                 Starboy     1 2017-01-01
#
#                        artist  \
# 0              Olivia Rodrigo
# 2                   Lil Nas X
# 8               Justin Bieber
# 16             Olivia Rodrigo
# 23                 The Weeknd
# ...                       ...
# 325200  The Weeknd, Daft Punk
# 325400  The Weeknd, Daft Punk
# 325600  The Weeknd, Daft Punk
# 325800  The Weeknd, Daft Punk
# 326000  The Weeknd, Daft Punk
#
#                                                       url          trend  \
# 0       https://open.spotify.com/track/4ZtFanR9U6ndgdd...  SAME_POSITION
# 2       https://open.spotify.com/track/67BtfxlNbhBmCDR...  SAME_POSITION
# 8       https://open.spotify.com/track/4iJyoBOLtHqaGxP...        MOVE_UP
# 16      https://open.spotify.com/track/5wANPM4fQCJwkGd...      MOVE_DOWN
# 23      https://open.spotify.com/track/0VjIjW4GlUZAMYd...      MOVE_DOWN
# ...                                                   ...            ...
# 325200  https://open.spotify.com/track/5aAx2yezTd8zXrk...  SAME_POSITION
# 325400  https://open.spotify.com/track/5aAx2yezTd8zXrk...  SAME_POSITION
# 325600  https://open.spotify.com/track/5aAx2yezTd8zXrk...  SAME_POSITION
# 325800  https://open.spotify.com/track/5aAx2yezTd8zXrk...  SAME_POSITION
# 326000  https://open.spotify.com/track/5aAx2yezTd8zXrk...  SAME_POSITION
#
#         streams
# 0       7397613
# 2       5089504
# 8       3640232
# 16      2634188
# 23      2231005
# ...         ...
# 325200  3579206
# 325400  3619247
# 325600  3563076
# 325800  3342769
# 326000  3135625
#
# [25806 rows x 7 columns]

# %%
streams_by_song = number_ones.pivot_table(index=['date'], columns='title',values='streams')

# %%
streams_by_song.plot(figsize=(20,20)).invert_yaxis()

# %% [markdown]
# Lets look at one song in particular - All I want for christmas.  Can we find other songs that follow this pattern?
